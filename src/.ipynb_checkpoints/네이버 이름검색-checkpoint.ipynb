# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import requests
import json
import pandas as pd
from tqdm.notebook import tqdm

# %%
data = pd.read_csv("data/movie_df.csv")  #2012/01/01~2020/02/09년도 박스오피스 데이터
data.head()
data.tail()
# Out:
#        Unnamed: 0      date  rnum  rank  rankInten rankOldAndNew   movieCd  \
# 29615       29615  20200209     6     6          0           OLD  20197390
# 29616       29616  20200209     7     7          0           OLD  20100312
# 29617       29617  20200209     8     8          0           OLD  20192300
# 29618       29618  20200209     9     9          2           OLD  20191109
# 29619       29619  20200209    10    10         -1           OLD  20198676
#
#            movieNm      openDt  salesAmt  salesShare  salesInten  salesChange  \
# 29615        조조 래빗  2020-02-05  89263280         2.5     3759100          4.4
# 29616          인셉션  2010-07-21  41559000         1.2    -1458800         -3.4
# 29617    스파이 지니어스   2020-01-22  28459500         0.8     1240800          4.6
# 29618     페인 앤 글로리  2020-02-05  21892080         0.6     1672060          8.3
# 29619  타오르는 여인의 초상  2020-01-16  22664240         0.6    -1186280         -5.0
#
#           salesAcc  audiCnt  audiInten  audiChange  audiAcc  scrnCnt  showCnt
# 29615    315305540     9980        410         4.3    36645      276      521
# 29616  44263035800     4622       -147        -3.1  5928845      148      308
# 29617   3660141900     3324        169         5.4   446276      225      297
# 29618    146116780     2519        234        10.2    18796      168      266
# 29619   1061354568     2429       -299       -11.0   126844      110      159

# %%
colums_to_save=["movieCd","movieNm"]
total =data[colums_to_save].drop_duplicates()
print(total["movieCd"].shape,"\n",total.head(10))
# Out:
# (2016,)
#      movieCd                              movieNm
# 0  20112207                       미션임파서블:고스트프로토콜
# 1  20110295                                마이 웨이
# 2  20112621                        셜록홈즈 : 그림자 게임
# 3  20113260                               퍼펙트 게임
# 4  20113271                        프렌즈: 몬스터섬의비밀
# 5  19940256                                라이온 킹
# 6  20113381                               오싹한 연애
# 7  20112709   극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」
# 8  20113311                            앨빈과 슈퍼밴드3
# 9  20112708  극장판 포켓몬스터 베스트 위시 「비크티니와 흑의 영웅 제크로무」

# %%
movie_date = data[["movieNm","date"]]

# %%
df_marge = pd.merge(total,movie_date,how='left', left_index=True, right_index=True)

# %%
df_marge.head(2016), df_marge.shape
# Out:
# (        movieCd            movieNm_x            movieNm_y      date
#  0      20112207       미션임파서블:고스트프로토콜       미션임파서블:고스트프로토콜  20120101
#  1      20110295                마이 웨이                마이 웨이  20120101
#  2      20112621        셜록홈즈 : 그림자 게임        셜록홈즈 : 그림자 게임  20120101
#  3      20113260               퍼펙트 게임               퍼펙트 게임  20120101
#  4      20113271        프렌즈: 몬스터섬의비밀         프렌즈: 몬스터섬의비밀   20120101
#  ...         ...                  ...                  ...       ...
#  29574  20191109             페인 앤 글로리             페인 앤 글로리  20200205
#  29575  20197390                조조 래빗                조조 래빗  20200205
#  29577  20192240               작은 아씨들               작은 아씨들  20200205
#  29584  20192984   극장판 미니특공대: 공룡왕 디노    극장판 미니특공대: 공룡왕 디노   20200206
#  29599  20191085  이 멋진 세계에 축복을! 붉은 전설  이 멋진 세계에 축복을! 붉은 전설  20200207
#
#  [2016 rows x 4 columns],
#  (2016, 4))

# %%
lpoint=[]
driver=webdriver.Chrome("C:/ChromeDriver/chromedriver.exe")

for name in tqdm(total["movieNm"]):
    movieNm=name
    driver.get("https://movie.naver.com/movie/search/result.nhn?query="+movieNm+"&section=movie&ie=utf8")
    try:
        point=driver.find_element_by_xpath("//*[@id='old_content']/ul[2]/li[1]/dl/dd[1]/em[1]")
    except:
        print("점수를 찾을수 없는 영화입니다. : ",name)
        
        lpoint.append(0)
        continue
    else:
        lpoint.append(point.text)
        #print(point.text)
        #point=''
        #rint(name," : ",point.text)
driver.close()
total["point"]=lpoint
total.head(10)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2016.0), HTML(value='')))
# 점수를 찾을수 없는 영화입니다. :  여성다큐멘터리스트-반이다1
# 점수를 찾을수 없는 영화입니다. :  언터처블: 1%의 우정
# 점수를 찾을수 없는 영화입니다. :  비정한 도시 감독판
# 점수를 찾을수 없는 영화입니다. :  헨젤과 그레텔: 마녀 사냥꾼 3D
# 점수를 찾을수 없는 영화입니다. :  퍼펙트
# 점수를 찾을수 없는 영화입니다. :  써드 퍼슨 - 감독판
# 점수를 찾을수 없는 영화입니다. :  BiFan2015 판타스틱 단편 걸작선 3
# 점수를 찾을수 없는 영화입니다. :  반지의 제왕 : 반지원정대 (확장판)
# 점수를 찾을수 없는 영화입니다. :  반지의 제왕 : 두개의 탑 (확장판)
# 점수를 찾을수 없는 영화입니다. :  반지의 제왕 : 왕의 귀환 (확장판)
# 점수를 찾을수 없는 영화입니다. :  인디애니페스트 2018 새벽비행 2
# 점수를 찾을수 없는 영화입니다. :  FIWOM 2018 웃어봐+수잔과 남자+내일, 또 내일, 그리고 또 내일+여자1 여자2 여자3+루비 파샤의 전설
# 점수를 찾을수 없는 영화입니다. :  터미네이터2 3D
#     movieCd                              movieNm point
# 0  20112207                       미션임파서블:고스트프로토콜  8.73
# 1  20110295                                마이 웨이   스웨덴
# 2  20112621                        셜록홈즈 : 그림자 게임  8.00
# 3  20113260                               퍼펙트 게임  8.94
# 4  20113271                        프렌즈: 몬스터섬의비밀   8.87
# 5  19940256                                라이온 킹  8.27
# 6  20113381                               오싹한 연애  8.54
# 7  20112709   극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」  7.79
# 8  20113311                            앨빈과 슈퍼밴드3  8.39
# 9  20112708  극장판 포켓몬스터 베스트 위시 「비크티니와 흑의 영웅 제크로무」  8.11

# %%
total.to_csv("data/박스오피스와평균평점.csv")
total.head(20)
# Out:
#       movieCd                              movieNm
# 0    20112207                       미션임파서블:고스트프로토콜
# 1    20110295                                마이 웨이
# 2    20112621                        셜록홈즈 : 그림자 게임
# 3    20113260                               퍼펙트 게임
# 4    20113271                        프렌즈: 몬스터섬의비밀
# 5    19940256                                라이온 킹
# 6    20113381                               오싹한 연애
# 7    20112709   극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」
# 8    20113311                            앨빈과 슈퍼밴드3
# 9    20112708  극장판 포켓몬스터 베스트 위시 「비크티니와 흑의 영웅 제크로무」
# 41   20113671                              원더풀 라디오
# 45   20113652                                 다크아워
# 89   20113636                             네버엔딩 스토리
# 99   20113643                                   파파
# 102  20113862                             장화신은 고양이
# 106  20110882                   밀레니엄 : 여자를 증오한 남자들
# 117  20113883                           초한지 - 천하대전
# 118  20113811                      코알라 키드 : 영웅의 탄생
# 171  20113743                                  댄싱퀸
# 172  20113535                               부러진 화살

# %%
lview=[]
driver=webdriver.Chrome("C:/ChromeDriver/chromedriver.exe")

for name in tqdm(total["movieNm"]):
    movieNm=name
    driver.get("https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=%EC%98%81%ED%99%94+"+movieNm)
    try:
        viewer=driver.find_element_by_xpath("//*[@id='movieEColl']/div[3]/div/div[1]/div[2]/dl[5]/dd/em")
    except:
        print("관객수를 찾을수 없는 영화입니다. : ",name)
        lview.append(0)
        continue
    else:
        lview.append(viewer.text)
        #rint(name," : ",point.text)
driver.close()
total["viewer"]=lview
total.head(10)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2016.0), HTML(value='')))
# 관객수를 찾을수 없는 영화입니다. :  극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」
# 관객수를 찾을수 없는 영화입니다. :  극장판 포켓몬스터 베스트 위시 「비크티니와 흑의 영웅 제크로무」
# 관객수를 찾을수 없는 영화입니다. :  다크아워
# 관객수를 찾을수 없는 영화입니다. :  여성다큐멘터리스트-반이다1
# 관객수를 찾을수 없는 영화입니다. :  워 호스
# 관객수를 찾을수 없는 영화입니다. :  종착역
# 관객수를 찾을수 없는 영화입니다. :  아이언 스카이
# 관객수를 찾을수 없는 영화입니다. :  비정한 도시 감독판
# 관객수를 찾을수 없는 영화입니다. :  업사이드 다운
# 관객수를 찾을수 없는 영화입니다. :  늑대소년-확장판
# 관객수를 찾을수 없는 영화입니다. :  저지드레드 3D
# 관객수를 찾을수 없는 영화입니다. :  극장판 포켓몬스터 베스트위시「큐레무 VS 성검사 케르디오」
# 관객수를 찾을수 없는 영화입니다. :  극장판 포켓몬스터 베스트위시「메로엣타의 반짝반짝 음악회」
# 관객수를 찾을수 없는 영화입니다. :  마마
# 관객수를 찾을수 없는 영화입니다. :  헨젤과 그레텔: 마녀 사냥꾼 3D
# 관객수를 찾을수 없는 영화입니다. :  스토커
# 관객수를 찾을수 없는 영화입니다. :  글래디에이터: 로마 영웅 탄생의 비밀 3D
# 관객수를 찾을수 없는 영화입니다. :  화이트 하우스 다운
# 관객수를 찾을수 없는 영화입니다. :  숨바꼭질
# 관객수를 찾을수 없는 영화입니다. :  스파이
# 관객수를 찾을수 없는 영화입니다. :  디스커넥트
# 관객수를 찾을수 없는 영화입니다. :  코비: 블루 엘리펀트의 전설
# 관객수를 찾을수 없는 영화입니다. :  넛잡: 땅콩 도둑들
# 관객수를 찾을수 없는 영화입니다. :  명탐정 코난 : 탐정들의 진혼가
# 관객수를 찾을수 없는 영화입니다. :  몬스터
# 관객수를 찾을수 없는 영화입니다. :  하늘을 나는 강아지, 비포와 친구들
# 관객수를 찾을수 없는 영화입니다. :  일대일
# 관객수를 찾을수 없는 영화입니다. :  로보싸커
# 관객수를 찾을수 없는 영화입니다. :  비포 : 치즈와 초콜릿을 찾아서
# 관객수를 찾을수 없는 영화입니다. :  해무(海霧)
# 관객수를 찾을수 없는 영화입니다. :  혼스
# 관객수를 찾을수 없는 영화입니다. :  스파이
# 관객수를 찾을수 없는 영화입니다. :  써드 퍼슨 - 감독판
# 관객수를 찾을수 없는 영화입니다. :  사이코패스
# 관객수를 찾을수 없는 영화입니다. :  쥬라기 월드
# 관객수를 찾을수 없는 영화입니다. :  심야식당
# 관객수를 찾을수 없는 영화입니다. :  BiFan2015 판타스틱 단편 걸작선 3
# 관객수를 찾을수 없는 영화입니다. :  아마조니아
# 관객수를 찾을수 없는 영화입니다. :  더 매직: 리틀톰과 도둑공주
# 관객수를 찾을수 없는 영화입니다. :  꾸루꾸루와 친구들: 무지개 나무의 비밀
# 관객수를 찾을수 없는 영화입니다. :  맥베스
# 관객수를 찾을수 없는 영화입니다. :  최강전사 미니특공대: 영웅의 탄생
# 관객수를 찾을수 없는 영화입니다. :  태양 아래
# 관객수를 찾을수 없는 영화입니다. :  다이노소어 어드벤처 : 백악기 공룡대백과
# 관객수를 찾을수 없는 영화입니다. :  BIFAN2016 판타스틱 단편 걸작선 1
# 관객수를 찾을수 없는 영화입니다. :  파워배틀 와치카 미니카 배틀리그: 불꽃의 질주
# 관객수를 찾을수 없는 영화입니다. :  고스트버스터즈
# 관객수를 찾을수 없는 영화입니다. :  인천상륙작전 : 익스텐디드 에디션(확장판)
# 관객수를 찾을수 없는 영화입니다. :  아이 엠 어 히어로
# 관객수를 찾을수 없는 영화입니다. :  킹 오브 프리즘
# 관객수를 찾을수 없는 영화입니다. :  세븐
# 관객수를 찾을수 없는 영화입니다. :  미스 사이공 : 25주년 특별 공연
# 관객수를 찾을수 없는 영화입니다. :  트롤
# 관객수를 찾을수 없는 영화입니다. :  극장판 어드벤처 타임: 비밀의 아일랜드
# 관객수를 찾을수 없는 영화입니다. :  더 플랜
# 관객수를 찾을수 없는 영화입니다. :  원더 우먼
# 관객수를 찾을수 없는 영화입니다. :  미이라
# 관객수를 찾을수 없는 영화입니다. :  첫키스만 50번째
# 관객수를 찾을수 없는 영화입니다. :  젝스키스 20주년 기념 하와이 영상 NEW KIES ON THE [HONOLULU]
# 관객수를 찾을수 없는 영화입니다. :  판타스틱 단편 걸작선 1
# 관객수를 찾을수 없는 영화입니다. :  극장판 위 베어 베어스: 곰 브라더스
# 관객수를 찾을수 없는 영화입니다. :  피터와 모글리의 크리스마스 어드벤처
# 관객수를 찾을수 없는 영화입니다. :  빅 배드 폭스
# 관객수를 찾을수 없는 영화입니다. :  주문은 토끼입니까?? ~디어 마이 시스터~
# 관객수를 찾을수 없는 영화입니다. :  문호 스트레이독스 [데드 애플]
# 관객수를 찾을수 없는 영화입니다. :  다이노 헌터: 티렉스VS파키리노 대격돌
# 관객수를 찾을수 없는 영화입니다. :  무문관
# 관객수를 찾을수 없는 영화입니다. :  위 베어 베어스: 베이비 베어스
# 관객수를 찾을수 없는 영화입니다. :  드래곤 프린세스
# 관객수를 찾을수 없는 영화입니다. :  인랑
# 관객수를 찾을수 없는 영화입니다. :  인디애니페스트 2018 새벽비행 2
# 관객수를 찾을수 없는 영화입니다. :  FIWOM 2018 웃어봐+수잔과 남자+내일, 또 내일, 그리고 또 내일+여자1 여자2 여자3+루비 파샤의 전설
# 관객수를 찾을수 없는 영화입니다. :  에그엔젤 코코밍: 두근두근 핼러윈 파티
# 관객수를 찾을수 없는 영화입니다. :  다이노 어드벤처2: 육해공 공룡 대백과
# 관객수를 찾을수 없는 영화입니다. :  박물관이 진짜 살아있다
# 관객수를 찾을수 없는 영화입니다. :  로빈슨의 언더워터 어드벤처
# 관객수를 찾을수 없는 영화입니다. :  투 프렌즈
# 관객수를 찾을수 없는 영화입니다. :  트와이스랜드
# 관객수를 찾을수 없는 영화입니다. :  러브 유어셀프 인 서울
# 관객수를 찾을수 없는 영화입니다. :  덤보
# 관객수를 찾을수 없는 영화입니다. :  킹 오브 프리즘 –샤이니 세븐 스타즈- II 카케루x조지x미나토
# 관객수를 찾을수 없는 영화입니다. :  고릴라와 슈퍼레이스
# 관객수를 찾을수 없는 영화입니다. :  킹 오브 프리즘 -샤이니 세븐 스타즈- Ⅲ 레오×유우×알렉
# 관객수를 찾을수 없는 영화입니다. :  이웃집 토토로
# 관객수를 찾을수 없는 영화입니다. :  엘리펀트킹 덤보
# 관객수를 찾을수 없는 영화입니다. :  BIFAN2019 판타스틱 단편 걸작선 1
# 관객수를 찾을수 없는 영화입니다. :  분노의 질주: 홉스&쇼
# 관객수를 찾을수 없는 영화입니다. :  발명왕 볼트
# 관객수를 찾을수 없는 영화입니다. :  꼬마 자전거 스피디
# 관객수를 찾을수 없는 영화입니다. :  빅 위시
# 관객수를 찾을수 없는 영화입니다. :  패트와 매트: 우당탕탕 크리스마스
# 관객수를 찾을수 없는 영화입니다. :  대통령의 7시간
# 관객수를 찾을수 없는 영화입니다. :  카운트다운
# 관객수를 찾을수 없는 영화입니다. :  아스테릭스: 마법 물약의 비밀
# 관객수를 찾을수 없는 영화입니다. :  하이큐!! 땅 VS 하늘
#     movieCd                              movieNm point       viewer
# 0  20112207                       미션임파서블:고스트프로토콜  8.73  7,508,976 명
# 1  20110295                                마이 웨이   스웨덴  2,142,670 명
# 2  20112621                        셜록홈즈 : 그림자 게임  8.00  2,239,156 명
# 3  20113260                               퍼펙트 게임  8.94  1,507,084 명
# 4  20113271                        프렌즈: 몬스터섬의비밀   8.87    549,904 명
# 5  19940256                                라이온 킹  8.27  4,743,264 명
# 6  20113381                               오싹한 연애  8.54  3,009,406 명
# 7  20112709   극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」  7.79            0
# 8  20113311                            앨빈과 슈퍼밴드3  8.39    570,150 명
# 9  20112708  극장판 포켓몬스터 베스트 위시 「비크티니와 흑의 영웅 제크로무」  8.11            0

# %%
total.to_csv("data/박스오피스와평균평점.csv")
total.head(20)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-11-72a6ceec56a8> in <module>
# ----> 1 total.to_csv("data/박스오피스와평균평점.csv")
#       2 total.head(20)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'data/박스오피스와평균평점.csv'

# %%
AT= pd.read_csv("data/ActMvList.csv")
AT.head(10)
# Out:
#    peopleCd peopleNm repRoleNm  \
# 0  20250610    너맨 아카        배우
# 1  20189239      김상일        배우
# 2  10004432      김상일        배우
# 3  20320869      박시현        배우
# 4  20316497      박시현        배우
# 5  20147497      박시현        배우
# 6  20287856      신중혁        배우
# 7  20294389      강소백        배우
# 8  10039587  스티븐 프라이        배우
# 9  20335401      한사명        배우
#
#                                           filmoNames
# 0                                             그레이트 월
# 1                                             화려한 외출
# 2                        가루지기|거룩한 계보|H(에이치)|뒤통수 조심해라
# 3                                                괴물들
# 4                                                 마녀
# 5                                          이불|달나라 여행
# 6                              크게 될 놈|악녀|특별시민|루시드 드림
# 7                         광대들: 풍문조작단|신과함께-죄와 벌|브이아이피
# 8                  무한대를 본 남자|소년의 집|브라이트 영 씽|썬더팬츠|와일드
# 9  해치지않아|얼굴없는 보스|메이트|흥부: 글로 세상을 바꾼 자|침묵|택시운전사|용순|...

# %%
for filmo in total["movieNm"]:
    print(AT[AT["filmoNames"].isin(filmo)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-0d65082b0a64> in <module>
#       1 for filmo in AT["filmoNames"]:
# ----> 2     if(total.movieNm.any(filmo.split("|"))):
#       3         print(AT.peopleNm)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in logical_func(self, axis, bool_only, skipna, level, **kwargs)
#   11365             skipna=skipna,
#   11366             numeric_only=bool_only,
# > 11367             filter_type="bool",
#   11368         )
#   11369
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3867
#    3868         if axis is not None:
# -> 3869             self._get_axis_number(axis)
#    3870
#    3871         if isinstance(delegate, Categorical):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     396     @classmethod
#     397     def _get_axis_number(cls, axis):
# --> 398         axis = cls._AXIS_ALIASES.get(axis, axis)
#     399         if is_integer(axis):
#     400             if axis in cls._AXIS_NAMES:
#
# TypeError: unhashable type: 'list'
