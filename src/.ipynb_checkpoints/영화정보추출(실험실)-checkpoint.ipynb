# %%
# by 최혜원 2020.2.10
# tqdm 수정 - 키값변경
import json
import pandas as pd
from urllib.request import urlopen
from datetime import datetime
from tqdm.notebook import tqdm

# movie_dict = {"date":[], "rnum":[],"rank":[],"rankInten":[],"rankOldAndNew":[],"movieCd":[],
#              "movieNm":[],"openDt":[],"salesAmt":[],"salesShare":[],"salesInten":[],
#              "salesChange":[],"salesAcc":[],"audiCnt":[],"audiInten":[],"audiChange":[],
#              "audiAcc":[],"scrnCnt":[],"showCnt":[]}
# keys = ['rnum',
#  'rank',
#  'rankInten',
#  'rankOldAndNew',
#  'movieCd',
#  'movieNm',
#  'openDt',
#  'salesAmt',
#  'salesShare',
#  'salesInten',
#  'salesChange',
#  'salesAcc',
#  'audiCnt',
#  'audiInten',
#  'audiChange',
#  'audiAcc',
#  'scrnCnt',
#  'showCnt']

# today = datetime.today().strftime("%Y-%m-%d")
# date = pd.date_range("2012-01-01", today)
# strdate = date.strftime("%Y%m%d")


# for day in tqdm(strdate):
#     response = urlopen("http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=761d541eb86d7ac8026b0746394d5361&targetDt="+day).read().decode('utf-8')
#     responseJson = json.loads(response)
#     daily_data = responseJson.get("boxOfficeResult").get("dailyBoxOfficeList")
#     for daily in range(len(daily_data)):
#         daily_data_rank = daily_data[daily]
#         movie_dict["date"].append(day)
#         for idx in keys:
#             movie_dict[idx].append(daily_data_rank[idx])

# %%
import requests
import json

key1="761d541eb86d7ac8026b0746394d5361"
key2="17792cac2e71366952c3c30b3ca61e40"
day="20180220"
url ="http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key="+key1+"&targetDt="+day
#print(url)

res= requests.get(url)
text=res.text

d = json.loads(text)

for b in d['boxOfficeResult']['dailyBoxOfficeList']:
    print(b['rank'],b['rankOldAndNew'],b['movieCd'],b['movieNm'],b['salesAmt'],b['audiCnt'])
# Out:
# 1 OLD 20170561 블랙 팬서 1339810000 171156
# 2 OLD 20168250 골든슬럼버 363771900 48097
# 3 OLD 20179205 조선명탐정: 흡혈괴마의 비밀 296878400 40315
# 4 OLD 20176121 흥부: 글로 세상을 바꾼 자 126100600 16983
# 5 OLD 20078561 명탐정 코난:감벽의 관 78434800 11466
# 6 OLD 20179985 코코 56664400 7967
# 7 OLD 20178672 패딩턴 2 52331600 7861
# 8 NEW 20170841 리틀 포레스트 46692700 6846
# 9 OLD 20176104 그것만이 내 세상 45505700 6623
# 10 OLD 20177946 월요일이 사라졌다 17183800 2449

# %%
#openStartDt
#http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json?key=430156241533f1d058c603178cc3ca0e&openStartDt=20120101
rownum="100"
url="http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json?key="+key1
url_json="&openStartDt=2012&openEndDt=2012&itemPerPage="+rownum


res= requests.get(url+url_json)
text=res.text

d = json.loads(text)
print(d['movieListResult']['totCnt'])
for b in d['movieListResult']['movieList']:
    print(b['movieNm'],b["movieCd"])
# Out:
# 651
# 비정한 도시 감독판 20121241
# 댄싱퀸 20113743
# 엄마에게 20090105
# 가문의 영광5 - 가문의 귀환 20128687
# 자칼이 온다 20126089
# 음치 클리닉  20125406
# sm 헌터 20124394
# 나는 공무원이다 20113391
# 철암 계곡의 혈투 20111027
# 용문비갑 20124944
# 강철대오:구국의 철가방 20124070
# 웨딩스캔들 20128707
# R2B: 리턴투베이스 20124049
# 늑대소년 20124054
# 오즈의 마법사 19398001
# 위험한 관계 20129626
# 파파 20113643
# 달팽이의 별 20100752
# 호빗: 뜻밖의 여정 20125048
# 연가시 20124062
# 파리의 도둑고양이 20125066
# 고양이를 빌려드립니다 20122861
# 블루 발렌타인 20126026
# 제7의 봉인 20070400
# 줄탁동시 20110985
# 해피 해피 브레드 20126446
# 청춘그루브 20116038
# 돈의 맛 20124064
# 피나 20128306
# 파닥파닥 20126010
# 케빈에 대하여 20113486
# 피라냐 3DD 20127407
# 미쓰 마마 20111898
# 만화방 20113322
# 시작은 키스! 20126408
# 페이스메이커 20113951
# 테이큰 2 20128447
# 캐빈 인 더 우즈 20126566
# 피에타 20124934
# 토리노의 말 20124427
# 더 그레이 20124021
# 야곱 신부의 편지 20125766
# 러브 20128308
# 주먹왕 랄프 20129388
# 체 게바라 : 뉴맨 20121683
# 남영동1985 20127546
# 두 개의 문 20112443
# 내가 살인범이다 20124075
# 장화신은 고양이 20113862
# 늑대아이 20127494
# 지난 여름, 갑자기 20126507
# 반드시 크게 들을 것 2 : Wild Days 20128609
# ...

# %%
field=("movieNm","typeNm","nations","genres","directors","actors")
moiveCd="20121421"
url="http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json"
url_order="?key="+key1+"&movieCd="+moiveCd
res= requests.get(url+url_order)
text=res.text

d = json.loads(text)
b = d.get("movieInfoResult").get("movieInfo").get("actors")[:][3]["peopleNm"]
#print(d)
for idx in d.get("movieInfoResult").get("movieInfo").get("actors")[:] :
    print(idx["peopleNm"])
# Out:
# 정인기
# 김지영
# 선우선
# 이명행
# 지우
# 최무성
# 장소연
# 박희본
# 황석정
# 박길수
# 박현영
# 이우정

# %%
import json
import pandas as pd
from urllib.request import urlopen
#from urllib2.request import urlopen
from datetime import datetime
from tqdm import tqdm_notebook
from pandas.io.json import json_normalize 

movie_df = pd.read_csv("data/movie_df.csv", encoding="utf-8")
movie_cd_list = list(movie_df["movieCd"])
movie_cd_list = list(set(movie_cd_list))
movie_info = {}

for cd in tqdm_notebook(movie_cd_list):
    response ="http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=c0e5d8d5a5cdc4b20f2edd996e8b9ea0&movieCd="+str(cd)
    hi_web = urlopen(res);
    with open('hi.json', 'ab') as hi_file:
          hi_file.write(hi_web.read())
# Out:
# C:\Users\kjjs1\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-678692b29095> in <module>
#      14 for cd in tqdm_notebook(movie_cd_list):
#      15     response ="http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=c0e5d8d5a5cdc4b20f2edd996e8b9ea0&movieCd="+str(cd)
# ---> 16     hi_web = urlopen(res);
#      17     with open('hi.json', 'ab') as hi_file:
#      18           hi_file.write(hi_web.read())
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
# ...

# %%
key1="761d541eb86d7ac8026b0746394d5361"
key2="17792cac2e71366952c3c30b3ca61e40"
data_info = pd.read_csv("data/movie_info.csv")  #2012/01/01~2020/02/09년도 박스오피스 데이터
data_info.head()
data_info.tail()
df = pd.DataFrame.from_dict(data_info,orient="columns")
df
# Out:
#       Unnamed: 0   movieCd                  movieNm  \
# 0       20135942  20135942     돌핀 : 꿈꾸는 다니엘의 용감한 모험
# 1       20152337  20152337  BiFan2015 판타스틱 단편 걸작선 3
# 2       20168721  20168721              아이엠스타 뮤직어워드
# 3       20176917  20176917                     램페이지
# 4       20185124  20185124             러브 유어셀프 인 서울
# ...          ...       ...                      ...
# 2011    20144102  20144102                  워터 디바이너
# 2012    20168688  20168688           레지던트 이블: 파멸의 날
# 2013    20168689  20168689     반지의 제왕 : 왕의 귀환 (확장판)
# 2014    20185081  20185081                 아이 필 프리티
# 2015    20193275  20193275           브링 더 소울 : 더 무비
#
#                                               movieNmEn  \
# 0                         THE DOLPHIN: STORY OF DREAMER
# 1                     BiFan2015 Fantastic Short Films 3
# 2     Aikatsu! Music Award: Minna de Shou wo Moracch...
# 3                                               Rampage
# ...

# %%
m_data=pd.read_csv("data/movie_2016_2018.csv")

# %%
m_data
# Out:
#        rnum  rank  rankInten rankOldAndNew   movieCd    movieNm      openDt  \
# 0         5     5          0           OLD  20157042   셜록: 유령신부  2016-01-02
# 1         5     5          0           OLD  20157042   셜록: 유령신부  2016-01-02
# 2         8     8          2           OLD  20157042   셜록: 유령신부  2016-01-02
# 3         5     5          0           OLD  20157042   셜록: 유령신부  2016-01-02
# 4         7     7          1           OLD  20157042   셜록: 유령신부  2016-01-02
# ...     ...   ...        ...           ...       ...        ...         ...
# 10696    10    10         -1           OLD  20170658  PMC: 더 벙커  2018-12-26
# 10697     4     4          0           OLD  20170658  PMC: 더 벙커  2018-12-26
# 10698     9     9         -5           OLD  20170658  PMC: 더 벙커  2018-12-26
# 10699     2     2          0           OLD  20170658  PMC: 더 벙커  2018-12-26
# 10700     2     2          0           OLD  20170658  PMC: 더 벙커  2018-12-26
#
# ...

# %%
total=m_data[["movieCd","movieNm"]].drop_duplicates()
total
# Out:
#         movieCd                          movieNm
# 0      20157042                         셜록: 유령신부
# 19     20153087                         포인트 브레이크
# 20     20150024   짱구는 못말려 극장판: 나의 이사 이야기 선인장 대습격
# 21     20155422                            굿 다이노
# 24     20142641                        나를 잊지 말아요
# ...         ...                              ...
# 10535  20183479  극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~
# 10585  20183375                극장판 포켓몬스터 모두의 이야기
# 10641  20186281                              범블비
# 10643  20183785            점박이 한반도의 공룡2 : 새로운 낙원
# 10681  20170658                        PMC: 더 벙커
#
# [752 rows x 2 columns]

# %%
total.to_csv("data/moiveList2016-2018.csv")

# %%
mp_data=pd.read_html("data/KOBIC 통계자료/검사외전.xls",encoding='UTF-8')[1]

# %%
mp_data
# Out:
#             날짜  스크린수 스크린점유율  상영횟수 상영점유율   좌석수 좌석점유율   좌석판매율       매출액  \
# 0   2016-01-25     4   0.1%     4    0%  1499  0.1%  100.0%   8994000
# 1   2016-01-26     3   0.1%     3    0%   772  0.0%  100.0%   6948000
# 2   2016-01-27     3   0.1%     3    0%  1002  0.0%  100.0%   9018000
# 3   2016-01-28     3   0.1%     4    0%  1508  0.1%  100.0%  11937000
# 4   2016-01-29    14   0.3%    14  0.1%  3303  0.1%   99.5%  29793000
# ..         ...   ...    ...   ...   ...   ...   ...     ...       ...
# 78  2016-11-29     1   0.0%     3    0%   780  0.0%   17.4%    272000
# 79  2016-11-30     1   0.0%     2    0%   520  0.0%   18.8%    196000
# 80  2016-12-02     1   0.0%     1    0%    76  0.0%    6.6%     45000
# 81  2016-12-03     1   0.0%     1    0%    76  0.0%    6.6%     45000
# 82  2016-12-05     1   0.0%     1    0%    76  0.0%    7.9%     54000
#
#             매출액증감(전일대비)   관객수      관객수증감(전일대비)        누적매출액    누적관객수   순위
# ...

# %%
mp_data=pd.read_html("data/KOBIC 통계자료/45년후.xls",encoding='UTF-8')[1]

# %%
mp_data
# Out:
#             날짜  스크린수 스크린점유율  상영횟수 상영점유율  좌석수 좌석점유율  좌석판매율      매출액  \
# 0   2015-11-26     1   0.0%     1    0%  293  0.0%  12.3%   254000
# 1   2015-11-28     1   0.0%     1    0%  293  0.0%  38.9%  1125000
# 2   2015-12-02     1   0.0%     1    0%  293  0.0%  28.3%   703000
# 3   2016-02-13     1   0.0%     1    0%  293  0.0%  32.4%   923000
# 4   2016-02-17     1   0.0%     1    0%  293  0.0%  14.0%   362000
# ..         ...   ...    ...   ...   ...  ...   ...    ...      ...
# 64  2016-07-01     1   0.0%     1    0%  152  0.0%   3.3%    30000
# 65  2016-07-02     1   0.0%     1    0%  152  0.0%   3.3%    39000
# 66  2016-07-05     1   0.0%     1    0%  152  0.0%   6.6%    76000
# 67  2017-10-19     1   0.0%     1    0%  850  0.0%   6.2%   299000
# 68  2018-02-14     1   0.0%     1    0%   77  0.0%   1.3%     6600
#
#            매출액증감(전일대비)  관객수     관객수증감(전일대비)      누적매출액  누적관객수   순위
# 0    254000 ( 100.0% )   36   36 ( 100.0% )     254000     36   63
# ...
